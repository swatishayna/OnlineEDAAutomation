# %%
import pandas as pd
import numpy as np



#dataframe = uploaded_file.read_datafolder()
df = pd.read_csv('D:\data science\ineuron\Project\python project\OnlineEDAAutomation\OnlineEDAAutomation\src\streamapps\stream_advancedapp\diabetes.csv')

# %%
categorical_column = [column for column in df.columns if df[column].dtypes == 'object']
categorical_stats = pd.DataFrame(df[categorical_column].describe())
categorical_stats
# Out:
#        BloodPressure
# count            764
# unique            50
# top               70
# freq              56

# %%
a = df['BloodPressure'].describe().loc['count']

# %%
df
# Out:
#      Pregnancies  Glucose BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0          ac c           35.0        0  33.6
# 1              1     85.0            bp           29.0        0  26.6
# 2              8    183.0            bp            0.0        0  23.3
# 3              1     89.0            bp           23.0       94  28.1
# 4              0      NaN            jf           35.0      168  43.1
# ..           ...      ...           ...            ...      ...   ...
# 763           10    101.0            76           48.0      180  32.9
# 764            2    122.0            70           27.0        0  36.8
# 765            5    121.0            72           23.0      112  26.2
# 766            1    126.0            60            0.0        0  30.1
# 767            1     93.0            70           31.0        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627   NaN      1.0
# ...
